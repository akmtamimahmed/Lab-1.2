# %%
import polars as pl
from pathlib import Path
from plotnine import (
    ggplot, aes, geom_line, labs, theme_light,
    geom_vline, geom_hline, annotate, scale_color_manual, ggsave
)

# %%
from plotnine import *

# Set the default figure size (width, height) in inches
options.figure_size = (12, 5)

# %%
def dh_state_expr():
    
    return (
        pl.when(pl.col("yearID") < 1973)
        .then(pl.lit("No DH (both)"))
        .when((pl.col("yearID").is_between(1973, 2019)) & (pl.col("lgID") == "AL"))
        .then(pl.lit("DH in AL; NL no DH"))
        .when((pl.col("yearID").is_between(1973, 2019)) & (pl.col("lgID") == "NL"))
        .then(pl.lit("NL no DH"))
        .when(pl.col("yearID") == 2020)
        .then(pl.lit("Universal DH (2020)"))
        .when((pl.col("yearID") == 2021) & (pl.col("lgID") == "AL"))
        .then(pl.lit("DH in AL; NL no DH"))
        .when((pl.col("yearID") == 2021) & (pl.col("lgID") == "NL"))
        .then(pl.lit("NL no DH"))
        .when(pl.col("yearID") >= 2022)
        .then(pl.lit("Universal DH (2022+)"))
        .otherwise(pl.lit("Unknown"))
        .alias("DH_state")
    )

# %%
# ERA Analysis
pitching_url = 'https://github.com/akmtamimahmed/Lab-1.2/raw/main/data/lahman_1871-2024_csv/lahman_1871-2024_csv/Pitching.csv'
pitch_df = pl.read_csv(pitching_url)
pitch_modern = pitch_df.filter(pl.col("yearID") >= 1946)

era_group = (
    pitch_modern
    .group_by(["yearID", "lgID"])
    .agg([
        pl.col("ER").sum().alias("total_ER"),
        pl.col("IPouts").sum().alias("total_IPouts"),
    ])
    .with_columns(
        (pl.col("total_ER") / pl.col("total_IPouts") * 27).alias("ERA")
    )
     .select(["yearID", "lgID", "ERA"])
    .sort("yearID")
)
era_group.head()
# Out:
# shape: (5, 3)
# ┌────────┬──────┬──────────┐
# │ yearID ┆ lgID ┆ ERA      │
# │ ---    ┆ ---  ┆ ---      │
# │ i64    ┆ str  ┆ f64      │
# ╞════════╪══════╪══════════╡
# │ 1946   ┆ AL   ┆ 3.503345 │
# │ 1946   ┆ NL   ┆ 3.41174  │
# │ 1947   ┆ NL   ┆ 4.066987 │
# │ 1947   ┆ AL   ┆ 3.705309 │
# │ 1948   ┆ NL   ┆ 3.954666 │
# └────────┴──────┴──────────┘

# %%
# Slugging Percentage Analysis
batting_url = 'https://github.com/akmtamimahmed/Lab-1.2/raw/main/data/lahman_1871-2024_csv/lahman_1871-2024_csv/Batting.csv'
bat_df = pl.read_csv(batting_url)
bat_modern = bat_df.filter(pl.col("yearID") >= 1946)

bat_group = (
    bat_modern
    .group_by(["yearID", "lgID"])
    .agg([
        pl.col("AB").sum().alias("total_AB"),
        pl.col("H").sum().alias("total_H"),
        pl.col("2B").sum().alias("total_2B"),
        pl.col("3B").sum().alias("total_3B"),
        pl.col("HR").sum().alias("total_HR"),
    ])
    .with_columns(
        (pl.col("total_H") + pl.col("total_2B") + 2 * pl.col("total_3B") + 3 * pl.col("total_HR")).alias("total_TB")
    )
    .with_columns(
        (pl.col("total_TB") / pl.col("total_AB")).alias("SLG")
    )
)
bat_group.head()
# Out:
# shape: (5, 9)
# ┌────────┬──────┬──────────┬─────────┬───┬──────────┬──────────┬──────────┬──────────┐
# │ yearID ┆ lgID ┆ total_AB ┆ total_H ┆ … ┆ total_3B ┆ total_HR ┆ total_TB ┆ SLG      │
# │ ---    ┆ ---  ┆ ---      ┆ ---     ┆   ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ i64    ┆ str  ┆ i64      ┆ i64     ┆   ┆ i64      ┆ i64      ┆ i64      ┆ f64      │
# ╞════════╪══════╪══════════╪═════════╪═══╪══════════╪══════════╪══════════╪══════════╡
# │ 1992   ┆ AL   ┆ 77147    ┆ 20006   ┆ … ┆ 386      ┆ 1776     ┆ 29702    ┆ 0.385005 │
# │ 1952   ┆ AL   ┆ 42317    ┆ 10690   ┆ … ┆ 339      ┆ 794      ┆ 15466    ┆ 0.36548  │
# │ 1994   ┆ NL   ┆ 55068    ┆ 14695   ┆ … ┆ 377      ┆ 1532     ┆ 22829    ┆ 0.41456  │
# │ 1975   ┆ AL   ┆ 65371    ┆ 16861   ┆ … ┆ 429      ┆ 1465     ┆ 24776    ┆ 0.379006 │
# │ 2001   ┆ NL   ┆ 88100    ┆ 23027   ┆ … ┆ 488      ┆ 2952     ┆ 37472    ┆ 0.425335 │
# └────────┴──────┴──────────┴─────────┴───┴──────────┴──────────┴──────────┴──────────┘

# %%
pl.read_csv("./data/league_era_by_year.csv").head()
# Out:
# shape: (5, 6)
# ┌────────┬──────┬──────────┬──────────────┬──────────┬────────────────────┐
# │ yearID ┆ lgID ┆ total_ER ┆ total_IPouts ┆ ERA      ┆ DH_state           │
# │ ---    ┆ ---  ┆ ---      ┆ ---          ┆ ---      ┆ ---                │
# │ i64    ┆ str  ┆ i64      ┆ i64          ┆ f64      ┆ str                │
# ╞════════╪══════╪══════════╪══════════════╪══════════╪════════════════════╡
# │ 1971   ┆ NL   ┆ 6738     ┆ 52427        ┆ 3.470082 ┆ No DH (both)       │
# │ 1948   ┆ NL   ┆ 4814     ┆ 32867        ┆ 3.954666 ┆ No DH (both)       │
# │ 1991   ┆ AL   ┆ 9290     ┆ 61146        ┆ 4.102149 ┆ DH in AL; NL no DH │
# │ 1969   ┆ NL   ┆ 6952     ┆ 52162        ┆ 3.598482 ┆ No DH (both)       │
# │ 1981   ┆ NL   ┆ 4514     ┆ 34906        ┆ 3.491606 ┆ NL no DH           │
# └────────┴──────┴──────────┴──────────────┴──────────┴────────────────────┘

# %%
pl.read_csv("./data/league_slugging_by_year.csv").head()
# Out:
# shape: (5, 10)
# ┌────────┬──────┬──────────┬─────────┬───┬──────────┬──────────┬──────────┬────────────────────┐
# │ yearID ┆ lgID ┆ total_AB ┆ total_H ┆ … ┆ total_HR ┆ total_TB ┆ SLG      ┆ DH_state           │
# │ ---    ┆ ---  ┆ ---      ┆ ---     ┆   ┆ ---      ┆ ---      ┆ ---      ┆ ---                │
# │ i64    ┆ str  ┆ i64      ┆ i64     ┆   ┆ i64      ┆ i64      ┆ f64      ┆ str                │
# ╞════════╪══════╪══════════╪═════════╪═══╪══════════╪══════════╪══════════╪════════════════════╡
# │ 1957   ┆ NL   ┆ 42919    ┆ 11162   ┆ … ┆ 1178     ┆ 17159    ┆ 0.3998   ┆ No DH (both)       │
# │ 1979   ┆ AL   ┆ 76704    ┆ 20682   ┆ … ┆ 2006     ┆ 31325    ┆ 0.408388 ┆ DH in AL; NL no DH │
# │ 1958   ┆ NL   ┆ 42143    ┆ 11026   ┆ … ┆ 1183     ┆ 17074    ┆ 0.405144 ┆ No DH (both)       │
# │ 1951   ┆ AL   ┆ 42361    ┆ 11103   ┆ … ┆ 839      ┆ 16154    ┆ 0.381341 ┆ No DH (both)       │
# │ 1948   ┆ AL   ┆ 42155    ┆ 11212   ┆ … ┆ 710      ┆ 16088    ┆ 0.381639 ┆ No DH (both)       │
# └────────┴──────┴──────────┴─────────┴───┴──────────┴──────────┴──────────┴────────────────────┘

# %%
era_wide = era_group.pivot(
    index="yearID",
    on="lgID",
    values="ERA"
)

# %%
era_plot_df = (
    era_wide
    .with_columns(
        (pl.col("AL") - pl.col("NL")).alias("AL - NL")
    )
    .unpivot(index="yearID", variable_name="League", value_name="ERA")
)

# %%
# Create the Visualization with plotnine
league_colors = {"AL": "#377eb8", "NL": "#4daf4a", "AL - NL": "#e41a1c"}
year_ticks = list(range(1950, 2021, 10))

era_plot = (
    ggplot(era_plot_df, aes(x="yearID", y="ERA", color="League"))
    + geom_line(size=1)
    + geom_hline(yintercept=0, linetype="dotted", color="gray", size=1)
    + geom_vline(xintercept=1973, linetype="dashed", color="orange", size=1)
    + geom_vline(xintercept=2020, linetype="dashed", color="#984ea3") 
    + geom_vline(xintercept=2022, linetype="dashed", color="brown")
    + annotate("text", x=1972, y=1.5, label="DH introduced to AL in 1973", ha="right", size=11, color="orange")
    + annotate("text", x=2019, y=2.50, label="Temporary Universal DH (2020)", ha="right", size=11, color="#984ea3")
    + annotate("text", x=2021.5, y=1.75, label="Permanent Universal DH (2022+)", ha="right", size=11, color="brown")
    + labs(
        title="Comparing league-wide ERA",
        subtitle="Dashed lines indicate Designated Hitter (DH) rule changes",
        x="yearID",
        y="League ERA",
        color="League"
    )
    + scale_color_manual(values=league_colors)
    + theme_light()
    + theme(axis_title=element_text(color="black", face="bold"),
        axis_text=element_text(color="black"))
    + scale_x_continuous(breaks=year_ticks)
   
)
ggsave(era_plot, filename="img/league_era_comparison.png", width=25, height=10, dpi=400)

era_plot
# Out:
# /root/anaconda3/lib/python3.12/site-packages/plotnine/ggplot.py:630: PlotnineWarning: Saving 25 x 10 in image.
# /root/anaconda3/lib/python3.12/site-packages/plotnine/ggplot.py:631: PlotnineWarning: Filename: img/league_era_comparison.png

# %%
# Load and Prepare Slugging Data
batting_url = 'https://github.com/akmtamimahmed/Lab-1.2/raw/main/data/lahman_1871-2024_csv/lahman_1871-2024_csv/Batting.csv'
bat_df = pl.read_csv(batting_url)
slg_group = (
    bat_df
    .filter((pl.col("yearID") >= 1946) & (pl.col("lgID").is_in(["AL", "NL"])))
    .group_by(["yearID", "lgID"])
    .agg(
        ((pl.col("H") + pl.col("2B") + 2 * pl.col("3B") + 3 * pl.col("HR")).sum() / pl.col("AB").sum()).alias("stat")
    )
    .sort("yearID")
)

# %%
# Wrangle Slugging Data for Plotting
slg_wide = slg_group.pivot(index="yearID", on="lgID", values="stat")
slg_plot_df = (
    slg_wide
    .with_columns((pl.col("AL") - pl.col("NL")).alias("AL - NL"))
    .unpivot(index="yearID", variable_name="League", value_name="SLG")
)

# %%
# Create Slugging Plot
slg_plot = (
    ggplot(slg_plot_df, aes(x="yearID", y="SLG", color="League")) 
    + geom_line(size=1)
    + geom_hline(yintercept=0, linetype="dotted", color="gray", size=1)
    + geom_vline(xintercept=1973, linetype="dashed", color="orange", size=1)
    + geom_vline(xintercept=2020, linetype="dashed", color="#984ea3")
    + geom_vline(xintercept=2022, linetype="dashed", color="brown")
    + annotate("text", x=1972, y=0.04, label="DH introduced to AL in 1973", ha="right", size=11, color="orange")
    + annotate("text", x=2019, y=0.25, label="Temporary Universal DH (2020)", ha="right", size=11, color="#984ea3")
    + annotate("text", x=2021.5, y=0.15, label="Permanent Universal DH (2022+)", ha="right", size=11, color="brown")
    + labs(
        title="Comparing league-wide Slugging Percentage",
        subtitle="Dashed lines indicate Designated Hitter (DH) rule changes",
        x="yearID", y="Slugging Pct.", color="League"
    )
    + scale_color_manual(values=league_colors)
    + theme_light()
    + theme(axis_title=element_text(color="black", face="bold"),
        axis_text=element_text(color="black"))
    + scale_x_continuous(breaks=year_ticks)

)
ggsave(slg_plot, filename="img/league_slugging_comparison.png", width=12, height=5, dpi=300)

slg_plot
# Out:
# /root/anaconda3/lib/python3.12/site-packages/plotnine/ggplot.py:630: PlotnineWarning: Saving 12 x 5 in image.
# /root/anaconda3/lib/python3.12/site-packages/plotnine/ggplot.py:631: PlotnineWarning: Filename: img/league_slugging_comparison.png

# %%
# Save both plots to PNG files
img_dir = Path("../Lab-1.2/img")
img_dir.mkdir(exist_ok=True)
era_plot_path = img_dir / "../img/league_era_comparison.png"
slg_plot_path = img_dir / "../img/league_slugging_comparison.png"

ggsave(era_plot, filename=era_plot_path, width=10, height=6, dpi=300)
ggsave(slg_plot, filename=slg_plot_path, width=10, height=6, dpi=300)

print(f"Plots saved to: \n- {era_plot_path}\n- {slg_plot_path}")
# Out:
# /root/anaconda3/lib/python3.12/site-packages/plotnine/ggplot.py:630: PlotnineWarning: Saving 10 x 6 in image.
# /root/anaconda3/lib/python3.12/site-packages/plotnine/ggplot.py:631: PlotnineWarning: Filename: ../Lab-1.2/img/../img/league_era_comparison.png
# /root/anaconda3/lib/python3.12/site-packages/plotnine/ggplot.py:630: PlotnineWarning: Saving 10 x 6 in image.
# /root/anaconda3/lib/python3.12/site-packages/plotnine/ggplot.py:631: PlotnineWarning: Filename: ../Lab-1.2/img/../img/league_slugging_comparison.png
# Plots saved to:
# - ../Lab-1.2/img/../img/league_era_comparison.png
# - ../Lab-1.2/img/../img/league_slugging_comparison.png

# %%
# Display the Plot
era_plot.show()
print("\nPlot saved to img/league_era_comparison.png")
slg_plot.show()
print("\nPlot saved to img/league_slugging_comparison.png")
# Out:
# Plot saved to img/league_era_comparison.png
# Plot saved to img/league_slugging_comparison.png
