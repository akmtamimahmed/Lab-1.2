# %%
import polars as pl
from pathlib import Path
from plotnine import *
from plotnine import options

# %%
# Set the default figure size (width, height) in inches
options.figure_size = (12, 5)

# %%
# Load pitching data and calculate ERA per league and year
(era_group := (
    pl.read_csv('https://github.com/akmtamimahmed/Lab-1.2/raw/main/data/lahman_1871-2024_csv/lahman_1871-2024_csv/Pitching.csv')
    .filter((pl.col("yearID") >= 1946) & (pl.col("lgID").is_in(["AL", "NL"])))
    .group_by(["yearID", "lgID"])
    .agg(
        (pl.col("ER").sum() / pl.col("IPouts").sum() * 27).alias("stat")
    )
    .sort("yearID")
    )
)
# Out:
# shape: (158, 3)
# ┌────────┬──────┬──────────┐
# │ yearID ┆ lgID ┆ stat     │
# │ ---    ┆ ---  ┆ ---      │
# │ i64    ┆ str  ┆ f64      │
# ╞════════╪══════╪══════════╡
# │ 1946   ┆ AL   ┆ 3.503345 │
# │ 1946   ┆ NL   ┆ 3.41174  │
# │ 1947   ┆ NL   ┆ 4.066987 │
# │ 1947   ┆ AL   ┆ 3.705309 │
# │ 1948   ┆ NL   ┆ 3.954666 │
# │ …      ┆ …    ┆ …        │
# │ 2022   ┆ NL   ┆ 4.053555 │
# │ 2023   ┆ AL   ┆ 4.280259 │
# │ 2023   ┆ NL   ┆ 4.383332 │
# │ 2024   ┆ NL   ┆ 4.138092 │
# │ 2024   ┆ AL   ┆ 4.019685 │
# └────────┴──────┴──────────┘

# %%
# Load batting data and calculate Slugging % per league and year
(slg_group := (
    pl.read_csv('https://github.com/akmtamimahmed/Lab-1.2/raw/main/data/lahman_1871-2024_csv/lahman_1871-2024_csv/Batting.csv')
    .filter((pl.col("yearID") >= 1946) & (pl.col("lgID").is_in(["AL", "NL"])))
    .group_by(["yearID", "lgID"])
    .agg(
        ((pl.col("H") + pl.col("2B") + 2 * pl.col("3B") + 3 * pl.col("HR")).sum() / pl.col("AB").sum()).alias("stat")
    )
    .sort("yearID")
    )
)
# Out:
# shape: (158, 3)
# ┌────────┬──────┬──────────┐
# │ yearID ┆ lgID ┆ stat     │
# │ ---    ┆ ---  ┆ ---      │
# │ i64    ┆ str  ┆ f64      │
# ╞════════╪══════╪══════════╡
# │ 1946   ┆ NL   ┆ 0.35549  │
# │ 1946   ┆ AL   ┆ 0.364142 │
# │ 1947   ┆ AL   ┆ 0.364459 │
# │ 1947   ┆ NL   ┆ 0.390394 │
# │ 1948   ┆ AL   ┆ 0.381639 │
# │ …      ┆ …    ┆ …        │
# │ 2022   ┆ AL   ┆ 0.391806 │
# │ 2023   ┆ AL   ┆ 0.411824 │
# │ 2023   ┆ NL   ┆ 0.416498 │
# │ 2024   ┆ AL   ┆ 0.394495 │
# │ 2024   ┆ NL   ┆ 0.403911 │
# └────────┴──────┴──────────┘

# %%
year_ticks = list(range(1950, 2021, 10))
league_colors = {"AL": "#377eb8", "NL": "#4daf4a", "AL - NL": "#e41a1c"} # Blue, Green, Red

# Plot 1: League-Wide ERA
(era_plot := (
    ggplot()
    + geom_line(
        data=era_group.filter(pl.col('lgID') == 'AL'),
        mapping=aes(x="yearID", y="stat", color="'AL'"), 
        size=1
    )
    + geom_line(
        data=era_group.filter(pl.col('lgID') == 'NL'),
        mapping=aes(x="yearID", y="stat", color="'NL'"),
        size=1
    )
    + geom_line(
        data=era_group.pivot(index="yearID", on="lgID", values="stat").with_columns(
            (pl.col("AL") - pl.col("NL")).alias("diff")
        ),
        mapping=aes(x="yearID", y="diff", color="'AL - NL'"),
        size=1
    )
    + scale_color_manual(values=league_colors, name="League")
    + scale_x_continuous(breaks=year_ticks)
    + geom_hline(yintercept=0, linetype="dotted", color="gray", size=1)
    + geom_vline(xintercept=1973, linetype="dashed", color="orange", size=1)
    + geom_vline(xintercept=2020, linetype="dashed", color="#984ea3", size=1)
    + geom_vline(xintercept=2022, linetype="dashed", color="#c51b7d", size=1)
    + annotate("text", x=1972, y=2.5, label="DH introduced to AL", ha="right", size=9, color="orange")
    + annotate("text", x=2019, y=1.75, label="Temporary Universal DH (2020)", ha="right", size=9, color="#984ea3")
    + annotate("text", x=2021.5, y=1.0, label="Permanent Universal DH (2022+)", ha="right", size=9, color="#c51b7d")
    + labs(
        title="Comparing League-Wide ERA",
        subtitle="Dashed lines indicate Designated Hitter (DH) rule changes",
        x="Year",
        y="League ERA" 
    )
    + theme_classic()
    + theme(axis_title=element_text(color="black", face="bold"), axis_text=element_text(color="black"))
    )
)

# %%
# Plot 2: League-Wide Slugging Percentage
(slg_plot := (
    ggplot()
    + geom_line(
        data=slg_group.filter(pl.col('lgID') == 'AL'),
        mapping=aes(x="yearID", y="stat", color="'AL'"),
        size=1
    )
    + geom_line(
        data=slg_group.filter(pl.col('lgID') == 'NL'),
        mapping=aes(x="yearID", y="stat", color="'NL'"),
        size=1
    )
    + geom_line(
        data=slg_group.pivot(index="yearID", on="lgID", values="stat").with_columns(
            (pl.col("AL") - pl.col("NL")).alias("diff")
        ),
        mapping=aes(x="yearID", y="diff", color="'AL - NL'"),
        size=1
    )
    + scale_color_manual(values=league_colors, name="League")
    + scale_x_continuous(breaks=year_ticks)
    + geom_hline(yintercept=0, linetype="dotted", color="gray", size=1)
    + geom_vline(xintercept=1973, linetype="dashed", color="orange", size=1)
    + geom_vline(xintercept=2020, linetype="dashed", color="#984ea3", size=1)
    + geom_vline(xintercept=2022, linetype="dashed", color="#c51b7d", size=1)
    + annotate("text", x=1972, y=0.04, label="DH introduced to AL", ha="right", size=9, color="orange")
    + annotate("text", x=2019, y=0.05, label="Temporary Universal DH (2020)", ha="right", size=9, color="#984ea3")
    + annotate("text", x=2020, y=-0.02, label="Permanent Universal DH (2022+)", ha="right", size=9, color="#c51b7d")
    + labs(
        title="Comparing League-Wide Slugging Percentage",
        subtitle="Dashed lines indicate Designated Hitter (DH) rule changes",
        x="Year", 
        y="Slugging Pct." 
    )
    + theme_classic()
    + theme(axis_title=element_text(color="black", face="bold"), axis_text=element_text(color="black"))
    )
)

# %%
# Save both plots to PNG files
img_dir = Path("../Lab-1.2/img")
img_dir.mkdir(exist_ok=True)
era_plot_path = img_dir / "../img/league_era_comparison.png"
slg_plot_path = img_dir / "../img/league_slugging_comparison.png"

ggsave(era_plot, filename=era_plot_path, width=10, height=6, dpi=300)
ggsave(slg_plot, filename=slg_plot_path, width=10, height=6, dpi=300)

print(f"Plots saved to: \n- {era_plot_path}\n- {slg_plot_path}")
# Out:
# /root/anaconda3/lib/python3.12/site-packages/plotnine/ggplot.py:630: PlotnineWarning: Saving 10 x 6 in image.
# /root/anaconda3/lib/python3.12/site-packages/plotnine/ggplot.py:631: PlotnineWarning: Filename: ../Lab-1.2/img/../img/league_era_comparison.png
# /root/anaconda3/lib/python3.12/site-packages/plotnine/ggplot.py:630: PlotnineWarning: Saving 10 x 6 in image.
# /root/anaconda3/lib/python3.12/site-packages/plotnine/ggplot.py:631: PlotnineWarning: Filename: ../Lab-1.2/img/../img/league_slugging_comparison.png
# Plots saved to:
# - ../Lab-1.2/img/../img/league_era_comparison.png
# - ../Lab-1.2/img/../img/league_slugging_comparison.png

# %%
# Display the Plot
era_plot.show()
print("\nPlot saved to img/league_era_comparison.png")
slg_plot.show()
print("\nPlot saved to img/league_slugging_comparison.png")
# Out:
# Plot saved to img/league_era_comparison.png
# Plot saved to img/league_slugging_comparison.png
